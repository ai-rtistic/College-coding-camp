# %%
from sklearn.datasets import load_boston     # bostion 데이터 불러오기(교육용)
from sklearn.preprocessing import PolynomialFeatures     # 다항회귀에서 다중 선형회귀로 변환 (입력 변수를 추가함)
from sklearn.model_selection import train_test_split     # train set, test set 나누기
from sklearn.linear_model import LinearRegression     # 선형 회귀 모델
from sklearn.metrics import mean_squared_error     # MSE (평균제곱오차) 함수

import pandas as pd

# %%
boston_dataset = load_boston()     # boston 데이터 불러오기

# %%
boston_dataset_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)
boston_dataset_df     # 원래 데이터 셋의 데이터 정보  -> 13개의 입력변수
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
polynomial_transformer = PolynomialFeatures(2)  # 2차 함수 (가설함수가 2차 함수)

polynomial_data = polynomial_transformer.fit_transform(boston_dataset.data)     # 다항회귀에서 다중 선형회귀로 변환

polynomial_feature_names = polynomial_transformer.get_feature_names(boston_dataset.feature_names)     # 입력 변수 feature name 가져오기

# %%
X = pd.DataFrame(polynomial_data, columns = polynomial_feature_names)     # 입력 변수 DataFrame 만들기

y = pd.DataFrame(boston_dataset.target, columns = ['MEDV'])     # 목표 변수 DataFrame 만들기

# %%
X     # 입력변수 13개 -> 105개로 증가
# Out:
#        1     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  ...  \
# 0    1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  ...
# 1    1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  ...
# 2    1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  ...
# 3    1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  ...
# 4    1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  ...
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  ...
# 502  1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  ...
# 503  1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  ...
# 504  1.0  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  ...
# 505  1.0  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  ...
#
# ...

# %%
y
# Out:
#      MEDV
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 501  22.4
# 502  20.6
# 503  23.9
# 504  22.0
# 505  11.9
#
# [506 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)     # train set, test set 뽑기

model = LinearRegression()     # 선형 회귀 모델 만들기
model.fit(X_train, y_train)     #선형 회귀 모델 train set 으로 학습시키기

y_test_prediction = model.predict(X_test)     # 가설함수로 test 값 예측

mean_squared_error(y_test, y_test_prediction) ** 0.5     # MSE 값에 제곱근 해서 모델 평가
# Out:
# 3.196527651029395
